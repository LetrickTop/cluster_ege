# %% [markdown]
# # Кластеризация ЕГЭ (8.5 если сделаны все задачи)

# %% [markdown]
# Рядом лежат экселевские таблицы с координатами точек. В 3 и 4 задаче используется манхетеское расстояние. В остальных Евклидово.
#
# * Постройте Распределение точек
# * Кластеризуйте руками
# * Постройте Распределение точек, отметьте принадлежность кластеров цветами
# * Найдите среди в каждом кластере точку расстояние от которой до всех остальных минимально
# * Выведите усреднение центров всех кластеров * 1000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import *

# %%
def zxc(claster):
  smin = float('inf')
  for i in range(len(claster)):
    s = 0
    for j in range(len(claster)):
      s += (((claster[i][0] - claster[j][0]) ** 2 + (claster[i][1] - claster[j][1]) ** 2) ** 0.5)
    if s < smin:
      smin = s
      x = claster[i][0]
      y = claster[i][1]
  return (x, y)
f = open('/content/0.txt')
claster1 = []
claster2 = []
a = []
f.readline()
n = nk = 0
for i in f.readlines():
  i = i.replace(',', '.')
  a.append(list(map(float, i.split())))
for i in a:
  if -1 <= i[0] <= 1.25 and 6 <= i[1] <= 10:
    claster1.append(i)
    n += 1
  elif 1 <= i[0] <= 3 and 4 <= i[1] <= 6.5:
    claster2.append(i)
    n += 1
  nk += 1
print(n, nk)
x1, y1 = zxc(claster1)
x2, y2 = zxc(claster2)
print((x1 + x2) / 2 * 1000)
print((y1 + y2) / 2 * 1000)

plt.figure(figsize=(10, 6))
plt.scatter([point[0] for point in claster1], [point[1] for point in claster1], color='blue', label='Cluster 1')
plt.scatter([point[0] for point in claster2], [point[1] for point in claster2], color='red', label='Cluster 2')
plt.scatter(x1, y1, color='black', marker='x', s=100, label='Centroid 1')
plt.scatter(x2, y2, color='black', marker='x', s=100, label='Centroid 2')
plt.legend()
plt.title('Распределение точек')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()
# Out:
# 100 100
# 1041.006278
# 6671.173406499999

# %%
def zxc(claster):
  smin = float('inf')
  for i in range(len(claster)):
    s = 0
    for j in range(len(claster)):
      s += (((claster[i][0] - claster[j][0]) ** 2 + (claster[i][1] - claster[j][1]) ** 2) ** 0.5)
    if s < smin:
      smin = s
      x = claster[i][0]
      y = claster[i][1]
  return (x, y)
f = open('/content/1.txt')
claster1 = []
claster2 = []
claster3 = []
a = []
f.readline()
for i in f.readlines():
  i = i.replace(',', '.')
  a.append(list(map(float, i.split())))
n = nk = 0
center1 = (10.0, 1.2)
a1, b1 = 1.3, 1.5
center2 = (8, -1)
a2, b2 = 1.5, 2
center3 = (6.5, 2.25)
a3, b3 = 1.5, 1.5

for i in a:
  if ((i[0] - center1[0]) ** 2) / (a1 ** 2) + ((i[1] - center1[1]) ** 2) / (b1 ** 2) <= 1:
    claster1.append(i)
    n += 1
  elif ((i[0] - center2[0]) ** 2) / (a2 ** 2) + ((i[1] - center2[1]) ** 2) / (b2 ** 2) <= 1:
    claster2.append(i)
    n += 1
  elif ((i[0] - center3[0]) ** 2) / (a3 ** 2) + ((i[1] - center3[1]) ** 2) / (b3 ** 2) <= 1:
    claster3.append(i)
    n += 1
  nk += 1

print(n, nk)
x1, y1 = zxc(claster1)
x2, y2 = zxc(claster2)
x3, y3 = zxc(claster3)
print((x1 + x2 + x3) / 3 * 1000)
print((y1 + y2 + y3) / 3 * 1000)

plt.figure(figsize=(10, 6))
plt.scatter([point[0] for point in claster1], [point[1] for point in claster1], color='blue', label='Cluster 1')
plt.scatter([point[0] for point in claster2], [point[1] for point in claster2], color='red', label='Cluster 2')
plt.scatter([point[0] for point in claster3], [point[1] for point in claster3], color='green', label='Cluster 2')
plt.scatter(x1, y1, color='black', marker='x', s=100, label='Centroid 1')
plt.scatter(x2, y2, color='black', marker='x', s=100, label='Centroid 2')
plt.scatter(x3, y3, color='black', marker='x', s=100, label='Centroid 3')
plt.legend()
plt.title('Распределение точек')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()
# Out:
# 9999 9999
# 8177.530805
# 738.4186756666666

# %%
def zxc(claster):
  smin = float('inf')
  for i in range(len(claster)):
    s = 0
    for j in range(len(claster)):
      s += abs(claster[i][0] - claster[j][0]) + abs(claster[i][1] - claster[j][1])
    if s < smin:
      smin = s
      x = claster[i][0]
      y = claster[i][1]
  return (x, y)
f = open('/content/2.txt')
claster1 = []
claster2 = []
a = []
f.readline()
n = nk = 0
for i in f.readlines():
  i = i.replace(',', '.')
  a.append(list(map(float, i.split())))
for i in a:
  if 2 <= i[0] <= 23 and 0 <= i[1] <= 12:
    claster1.append(i)
    n += 1
  elif 24 <= i[0] <= 46 and -10 <= i[1] <= 1:
    claster2.append(i)
    n += 1
  nk += 1
print(n, nk)
x1, y1 = zxc(claster1)
x2, y2 = zxc(claster2)
print((x1 + x2) / 2 * 1000)
print((y1 + y2) / 2 * 1000)

plt.figure(figsize=(10, 6))
plt.scatter([point[0] for point in claster1], [point[1] for point in claster1], color='blue', label='Cluster 1')
plt.scatter([point[0] for point in claster2], [point[1] for point in claster2], color='red', label='Cluster 2')
plt.scatter(x1, y1, color='black', marker='x', s=100, label='Centroid 1')
plt.scatter(x2, y2, color='black', marker='x', s=100, label='Centroid 2')
plt.legend()
plt.title('Распределение точек')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()
# Out:
# 999 999
# 23509.902664999998
# 554.6822819999999

# %%
def zxc(claster):
  smin = float('inf')
  for i in range(len(claster)):
    s = 0
    for j in range(len(claster)):
      s += abs(claster[i][0] - claster[j][0]) + abs(claster[i][1] - claster[j][1])
    if s < smin:
      smin = s
      x = claster[i][0]
      y = claster[i][1]
  return (x, y)
f = open('/content/3.txt')
claster1 = []
claster2 = []
claster3 = []
a = []
n = nk = 0
for i in f.readlines():
  i = i.replace(',', '.')
  a.append(list(map(float, i.split())))
for i in a:
  if -8 <= i[0] <= 16 and -2 <= i[1] <= 10:
    claster1.append(i)
    n += 1
  elif 20 <= i[0] <= 42 and -10 <= i[1] <= 2:
    claster2.append(i)
    n += 1
  elif -36 <= i[0] <= -14 and -20 <= i[1] <= -8:
    claster3.append(i)
    n += 1
  nk += 1
print(n, nk)
x1, y1 = zxc(claster1)
x2, y2 = zxc(claster2)
x3, y3 = zxc(claster3)
print((x1 + x2 + x3) / 3 * 1000)
print((y1 + y2 + y3) / 3 * 1000)

plt.figure(figsize=(10, 6))
plt.scatter([point[0] for point in claster1], [point[1] for point in claster1], color='blue', label='Cluster 1')
plt.scatter([point[0] for point in claster2], [point[1] for point in claster2], color='red', label='Cluster 2')
plt.scatter([point[0] for point in claster3], [point[1] for point in claster3], color='green', label='Cluster 2')
plt.scatter(x1, y1, color='black', marker='x', s=100, label='Centroid 1')
plt.scatter(x2, y2, color='black', marker='x', s=100, label='Centroid 2')
plt.scatter(x3, y3, color='black', marker='x', s=100, label='Centroid 3')
plt.legend()
plt.title('Распределение точек')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()
# Out:
# 10000 10000
# 3078.8940146666646
# -4758.945237

# %%
def zxc(claster):
  smin = float('inf')
  for i in range(len(claster)):
    s = 0
    for j in range(len(claster)):
      s += (((claster[i][0] - claster[j][0]) ** 2 + (claster[i][1] - claster[j][1]) ** 2) ** 0.5)
    if s < smin:
      smin = s
      x = claster[i][0]
      y = claster[i][1]
  return (x, y)
f = open('/content/4.txt')
claster1 = []
claster2 = []
a = []
f.readline()
n = nk = 0
for i in f.readlines():
  i = i.replace(',', '.')
  a.append(list(map(float, i.split())))
for i in a:
  if i[1] < i[0] + 2:
    claster1.append(i)
    n += 1
  else:
    claster2.append(i)
    #n += 1
  nk += 1
print(n, nk)
x1, y1 = zxc(claster1)
x2, y2 = zxc(claster2)
print((x1 + x2) / 2 * 1000)
print((y1 + y2) / 2 * 1000)

plt.figure(figsize=(10, 6))
plt.scatter([point[0] for point in claster1], [point[1] for point in claster1], color='blue', label='Cluster 1')
plt.scatter([point[0] for point in claster2], [point[1] for point in claster2], color='red', label='Cluster 2')
plt.scatter(x1, y1, color='black', marker='x', s=100, label='Centroid 1')
plt.scatter(x2, y2, color='black', marker='x', s=100, label='Centroid 2')
plt.legend()
plt.title('Распределение точек')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()
# Out:
# 250 500
# 2588.539922
# 4996.5675034999995

# %%
def zxc(claster):
  smin = float('inf')
  for i in range(len(claster)):
    s = 0
    for j in range(len(claster)):
      s += (((claster[i][0] - claster[j][0]) ** 2 + (claster[i][1] - claster[j][1]) ** 2) ** 0.5)
    if s < smin:
      smin = s
      x = claster[i][0]
      y = claster[i][1]
  return (x, y)
f = open('/content/5.txt')
f.readline()
claster1 = []
claster2 = []
claster3 = []
a = []
n = nk = 0
for i in f.readlines():
  i = i.replace(',', '.')
  a.append(list(map(float, i.split())))
for i in a:
  if i[0] < 0 and i[1] < 3.5:
    claster1.append(i)
    n += 1
  elif 0.5 <= i[0] <= 7 and i[1] <= i[0] + 3.5:
    claster2.append(i)
    n += 1
  elif i[1] > 3.5 and i[1] > i[0] + 3.5:
    claster3.append(i)
    n += 1
  nk += 1
print(n, nk)
x1, y1 = zxc(claster1)
x2, y2 = zxc(claster2)
x3, y3 = zxc(claster3)
print((x1 + x2 + x3) / 3 * 1000)
print((y1 + y2 + y3) / 3 * 1000)

plt.figure(figsize=(10, 6))
plt.scatter([point[0] for point in claster1], [point[1] for point in claster1], color='blue', label='Cluster 1')
plt.scatter([point[0] for point in claster2], [point[1] for point in claster2], color='red', label='Cluster 2')
plt.scatter([point[0] for point in claster3], [point[1] for point in claster3], color='green', label='Cluster 2')
plt.scatter(x1, y1, color='black', marker='x', s=100, label='Centroid 1')
plt.scatter(x2, y2, color='black', marker='x', s=100, label='Centroid 2')
plt.scatter(x3, y3, color='black', marker='x', s=100, label='Centroid 3')
plt.legend()
plt.title('Распределение точек')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
plt.show()
# Out:
# 9999 9999
# 61.652188666666625
# 3723.362146333333

# %% [markdown]
# # Кластеризация (0.75 за каждый алгоритм на всех данных)

# %% [markdown]
# На предложенных распределениях данных проверьте предложенные алгоритмы. Постройте графики кластеризации для каждой пары алгоритм-данные, разные кластеры покрасьте разным цветом. Воспользуйтесь sklearn реализациями. Параметры кластеризации для разных алгоритмов подберите такие, чтобы алгоритмы можно было сравнивать (по возможности одинаковое количество кластеров и т.д.)

# %%
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

# %%
two_means =
dbscan =

clustering_algorithms = (
        ("MiniBatch\nKMeans", two_means),
        ("DBSCAN", dbscan),
    )

# %%
np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 13))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.05, hspace=0.01
)

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 10,
    "n_clusters": 3,
    "min_samples": 20,
    "xi": 0.05,
    "min_cluster_size": 0.1,
}

datasets = [
    (
        noisy_circles,
        {
            "damping": 0.77,
            "preference": -240,
            "quantile": 0.2,
            "n_clusters": 2,
            "min_samples": 20,
            "xi": 0.25,
        },
    ),
    (noisy_moons, {"damping": 0.75, "preference": -220, "n_clusters": 2}),
    (
        varied,
        {
            "eps": 0.18,
            "n_neighbors": 2,
            "min_samples": 5,
            "xi": 0.035,
            "min_cluster_size": 0.2,
        },
    ),
    (
        aniso,
        {
            "eps": 0.15,
            "n_neighbors": 2,
            "min_samples": 20,
            "xi": 0.1,
            "min_cluster_size": 0.2,
        },
    ),
    (blobs, {}),
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])

    # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params["n_neighbors"], include_self=False
    )
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    for name, algorithm in clustering_algorithms:
        t0 = time.time()
